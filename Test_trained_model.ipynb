# %% [markdown]
# To use this model just copy any image to folder img then run the program

# %%
# load some packages
import keras
import matplotlib.pyplot as plt
from skimage.transform import resize
from keras import models
import numpy as np 
import glob

# %%
#Load model

model = keras.models.load_model('model.hdf5')

# test with any images just put image inside the folder Img
image_test = '../nguyen_van_han/Img/' # image test path
file_paths1 = glob.glob(image_test + '/*.jpg')[:10] # how many number want to test

for file_path in  file_paths1:
    
    img1 = plt.imread(file_path)
    img1_resize = resize(img1,(128,128))
    img1_resize = np.expand_dims(img1_resize,axis=0)
    results1 = model.predict(img1_resize)
    
    plt.imshow(img1)
    if int(results1*2)>=1:
        precentage = (round(float(((results1[0]-0.5 ) +0.5 )* 100 ),2))
        title = f"Male:{precentage}%"
    else:
        precentage = (round(float(((0.5-results1[0])+0.5)* 100 ),2))
        title = f"Female:{precentage}%"
    plt.title(title)
    plt.show()
# Out:
# 1/1 [==============================] - 0s 116ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 27ms/step
